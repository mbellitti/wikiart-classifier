# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %% [markdown]
# I am following this tutorial
# https://realpython.com/python-web-scraping-practical-introduction/

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
#from mathematicians import simple_get
raw_html = simple_get('https://realpython.com')
len(raw_html)
# Out:
# 278891

# %%
soup = BeautifulSoup(raw_html, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <link href="//files.realpython.com" rel="dns-prefetch"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
#   <title>
#    Python Tutorials – Real Python
#   </title>
#   <meta content="Real Python" name="author"/>
#   <meta content="Learn Python online: Python tutorials for developers of all skill levels, Python books and courses, Python news, code examples, articles, and more." name="description"/>
#   <meta content="" name="keywords"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link href="https://realpython.com/" rel="canonical"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="https://realpython.com/static/social-default-image.5e1aa4786b3a.png" property="twitter:image"/>
# ...

# %%
no_html = simple_get('https://realpython.com/blog/nope-not-gonna-find-it')
no_html is None
# Out:
# True

# %% [markdown]
# Now I am following this
# https://www.dataquest.io/blog/web-scraping-tutorial-python/

# %%
import requests

page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")
page
# Out:
# <Response [200]>

# %%
page.content
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
list_web=list(soup.children)

# %%
list_web[0], list_web[1], list_web[2]
# Out:
# ('html', '\n', <html>
#  <head>
#  <title>A simple example page</title>
#  </head>
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>
#  </html>)

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.NavigableString, bs4.element.Tag]

# %%
list_web2=list(list_web[2].children)

# %%
p=list(list_web2[3].children)[1]

# %%
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %%
soup = BeautifulSoup(page.content, 'html.parser')
p=soup.find_all('p')

# %%
p[0].get_text()
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# A trial run

# %%
import requests

page_image = requests.get("https://uploads1.wikiart.org/images/francesco-clemente/the-four-corners-1985.jpg")
print(page_image.status_code)
# Out:
# 200

# %%
import requests

url = "https://uploads1.wikiart.org/images/francesco-clemente/the-four-corners-1985.jpg"
response = requests.get(url)
if response.status_code == 200:
    with open("sample.jpg", 'wb') as f:
        f.write(response.content)

# %%
url = "https://www.wikiart.org/en/francesco-clemente/the-four-corners-1985"
page_trial_wikiart = requests.get(url)

# %%
from bs4 import BeautifulSoup
page_trial_wikiart_html = BeautifulSoup(page_trial_wikiart.content, 'html.parser')

# %%
search_image_line=page_trial_wikiart_html.find_all(class_='ms-zoom-cursor')

# %%
print(search_image_line)
# Out:
# [<img alt="The Four Corners, 1985 - Francesco Clemente" class="ms-zoom-cursor" itemprop="image" src="https://uploads1.wikiart.org/images/francesco-clemente/the-four-corners-1985.jpg" title="The Four Corners, 1985 - Francesco Clemente"/>]

# %%
start_index=str_list.find('\"')
end_index=str_list.find('\"', start_index+1)

# %%
str_list=str(search_image_line[0])

# %%
temp_var=[]
for i in range(len(str_list)):
    j=0
    #if str_list[i:i+1]
    if str_list[i:i+3]=="src":
        start_index=str_list.find('\"',i+3)
        print(start_index)
        end_index=str_list.find('\"', start_index+1)
        print(end_index)
        for j in range(start_index+1, end_index):
            temp_var.append(str_list[j])
        print(temp_var)
        #n=4
        #while n>0:
        #    print(str_list[j+i+5])
        #    if str_list[j+i+4]=='\"':
        ##        n=-1
        #j=j+1
# Out:
# 99
# 180
# ['h', 't', 't', 'p', 's', ':', '/', '/', 'u', 'p', 'l', 'o', 'a', 'd', 's', '1', '.', 'w', 'i', 'k', 'i', 'a', 'r', 't', '.', 'o', 'r', 'g', '/', 'i', 'm', 'a', 'g', 'e', 's', '/', 'f', 'r', 'a', 'n', 'c', 'e', 's', 'c', 'o', '-', 'c', 'l', 'e', 'm', 'e', 'n', 't', 'e', '/', 't', 'h', 'e', '-', 'f', 'o', 'u', 'r', '-', 'c', 'o', 'r', 'n', 'e', 'r', 's', '-', '1', '9', '8', '5', '.', 'j', 'p', 'g']

# %%
start_index=str_list.find('\"')
end_index=str_list.find('\"', start_index+1)

# %%
print(start_index)
print(end_index)
# Out:
# 9
# 53

# %%
web_address=''.join(temp_var)

# %%
web_address
# Out:
# 'https://uploads1.wikiart.org/images/francesco-clemente/the-four-corners-1985.jpg'
